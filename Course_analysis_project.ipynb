# %%
import pickle
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
pkl_file = open('data.pkl', 'rb')

letters_curvature_1 = pickle.load(pkl_file)

# %%
pkl_file = open('data2.pkl', 'rb')

letters_curvature_2 = pickle.load(pkl_file)

# %%
pkl_file = open('data3.pkl', 'rb')

letters_curvature_3 = pickle.load(pkl_file)

# %%
pkl_file = open('data4.pkl', 'rb')

letters_curvature_4 = pickle.load(pkl_file)

# %%
pkl_file = open('data5.pkl', 'rb')

letters_curvature_5 = pickle.load(pkl_file)

# %%
pkl_file = open('data6.pkl', 'rb')

letters_curvature_6 = pickle.load(pkl_file)

# %%
pkl_file = open('data7.pkl', 'rb')

letters_curvature_7 = pickle.load(pkl_file)

# %%
pkl_file = open('data8.pkl', 'rb')

letters_curvature_8 = pickle.load(pkl_file)

# %%
pkl_file = open('data9.pkl', 'rb')

letters_curvature_9 = pickle.load(pkl_file)

# %%
pkl_file = open('data10.pkl', 'rb')

letters_curvature_10 = pickle.load(pkl_file)

# %%
pkl_file = open('data11.pkl', 'rb')

letters_curvature_11 = pickle.load(pkl_file)

# %%
plt.plot(letters_curvature_9['ya'])

# %%
letters_curvature = []

# %%
letters_curvature.append(letters_curvature_1)
letters_curvature.append(letters_curvature_2)
letters_curvature.append(letters_curvature_3)
letters_curvature.append(letters_curvature_4)
letters_curvature.append(letters_curvature_5)
letters_curvature.append(letters_curvature_6)
letters_curvature.append(letters_curvature_7)
letters_curvature.append(letters_curvature_8)
letters_curvature.append(letters_curvature_9)
letters_curvature.append(letters_curvature_10)
letters_curvature.append(letters_curvature_11)

# %%
pkl_file = open('unill_data.pkl', 'rb')

control_curvature = pickle.load(pkl_file)

# %%
letters_curvature[0]['k'] = [11.230014]

# %%
fig, axs = plt.subplots(4, 3)

letter = 'sha'
for i in range(11):
    axs[i//3][i%3].plot(np.abs(letters_curvature[i][letter]))

# %%
plt.plot(np.abs(control_curvature['sha']))

# %%
fig, axs = plt.subplots(4, 3)

letter = 'a'
for i in range(11):
    axs[i//3][i%3].hist(np.abs(letters_curvature[i][letter]), log = True)

# %%
letter = 'zh'

for i in range(11):
    print(np.quantile(np.abs(letters_curvature[i][letter]), 0.97))
# Out:
# 92.90150604893635
# 79.70155064911972
# 64.68310483309831
# 78.0777858382193
# 51.80089462377824
# 88.74219607233837
# 89.81438096377406
# 99.3900166695414
# 60.97578792542661
# 108.93899294032178
# 60.441181140341705

# %%
letter = 'sha'

for i in range(11):
    print(len(letters_curvature[i][letter]))
# Out:
# 270
# 394
# 248
# 228
# 152
# 277
# 303
# 124
# 292
# 160
# 182

# %%
letters = ['a', 'b', 'v', 'g', 'd', 'ye', 'zh', 'z', 'i', 'k', 'l',\
           'm', 'n', 'o', 'p', 'r', 's', 't', 'y', 'ph', 'h', 'c',\
           'ch', 'sh', 'sha', 'bl', 'myagk', 'e', 'u', 'ya']

# %%
max_mean_curv = []
for i in range(11):
    cur_curv = []
    for letter in letters:
        cur_curv.append((np.abs(letters_curvature[i][letter]).mean(), letter))
    max_mean_curv.append(max(cur_curv))
    
max_mean_curv
# Out:
# C:\Users\Egor\AppData\Local\Temp\ipykernel_10632\3270169906.py:5: RuntimeWarning: Mean of empty slice.
#   cur_curv.append((np.abs(letters_curvature[i][letter]).mean(), letter))
# [(73.17185661545193, 'o'),
#  (837.358709944021, 'i'),
#  (136.74988834710268, 'sh'),
#  (54.83940554502976, 'h'),
#  (85.8561177588837, 'u'),
#  (20.29006023327209, 'bl'),
#  (21.935070785694734, 'u'),
#  (41.5111634166669, 'm'),
#  (16.65014141594615, 'y'),
#  (386.31950036406175, 't'),
#  (27.38338046475928, 'z')]

# %%
max_curv = []
for i in range(11):
    cur_curv = []
    for letter in letters:
        cur_curv.append((max(np.abs(np.concatenate((letters_curvature[i][letter], [0])))), letter))
    max_curv.append(max(cur_curv))
    
max_curv
# Out:
# [(4937.128169424552, 'b'),
#  (148995.47511271838, 'i'),
#  (39199.99999974488, 'sh'),
#  (7920.47782800042, 'h'),
#  (9804.589595733172, 'u'),
#  (1501.0170905952557, 'bl'),
#  (3429.8877575050446, 'u'),
#  (5749.333333327999, 'm'),
#  (500.5549721219472, 's'),
#  (36735.999999807864, 't'),
#  (3177.71298904436, 'z')]

# %%
min_mean_curv = []
for i in range(11):
    cur_curv = []
    for letter in letters:
        cur_curv.append((np.abs(letters_curvature[i][letter]).mean(), letter))
    min_mean_curv.append(min(cur_curv))
    
min_mean_curv
# Out:
# C:\Users\Egor\AppData\Local\Temp\ipykernel_10632\254566474.py:5: RuntimeWarning: Mean of empty slice.
#   cur_curv.append((np.abs(letters_curvature[i][letter]).mean(), letter))
# [(4.96219960177733, 'a'),
#  (4.223812775544264, 's'),
#  (3.270600212821445, 'o'),
#  (3.50549914063127, 'o'),
#  (2.11073118855347, 'o'),
#  (3.2936308384064557, 'o'),
#  (4.957498190480314, 'ye'),
#  (2.8334736104764424, 'o'),
#  (2.7335177291117634, 'o'),
#  (3.43716297884672, 'o'),
#  (3.035135643479084, 'b')]

# %%
letters_curvature_mean = []

for i in range(11):
    tmp = []
    for letter in letters:
        tmp.append(np.abs(letters_curvature[i][letter]).mean())
    letters_curvature_mean.append(tmp)

# %%
mean_df = pd.DataFrame(letters_curvature_mean, columns = [i + '_mean' for i in letters])
mean_df
# Out:
#        a_mean     b_mean     v_mean     g_mean     d_mean   ye_mean  \
# 0    4.962200  33.915890   9.483827  10.712904   8.640481  7.803905
# 1    8.345209   8.980513   8.797521  10.536539   6.329129  5.950748
# 2   12.136862   8.226751  24.168848   6.512061   9.185195  6.296802
# 3    5.316010  11.480554   8.097031   9.209834   9.862596  7.248029
# 4    6.901075  12.330023  13.343976  10.621428   9.083266  6.593191
# 5    5.319367  10.489231   5.566620  13.336186   4.892250  6.424238
# 6    5.648752  11.162153   7.586185   7.077240   8.760291  4.957498
# 7    5.962072   6.926451  11.852310   7.249400   7.089199  5.090029
# 8    7.607710   7.490143   7.161612   9.031328  10.998227  5.838970
# 9    6.385164  37.179136   9.247736  10.718950   9.401048  6.202279
# 10   6.293277   3.035136   5.702545   8.296173   4.269528  4.789586
#
#       zh_mean     z_mean      i_mean     k_mean  ...     h_mean     c_mean  \
# ...

# %%
scaler = StandardScaler()
mean_df_scaled = pd.DataFrame(scaler.fit_transform(mean_df), columns = [i + '_mean' for i in letters])
mean_df_scaled
# Out:
#       a_mean    b_mean    v_mean    g_mean    d_mean   ye_mean   zh_mean  \
# 0  -0.946846  1.904327 -0.121969  0.680597  0.293164  1.900644  0.632026
# 1   0.789428 -0.450036 -0.259686  0.589787 -0.847571 -0.177047 -0.185480
# 2   2.735432 -0.521205  2.824788 -1.482409  0.562000  0.210937 -0.108557
# 3  -0.765259 -0.213986 -0.400250 -0.093331  0.896322  1.277417 -0.509352
# 4   0.048250 -0.133780  0.652624  0.633496  0.511694  0.543237 -2.016518
# 5  -0.763536 -0.307585 -0.908012  2.031320 -1.556723  0.353813  0.239535
# 6  -0.594484 -0.244049 -0.502758 -1.191399  0.352295 -1.290642 -0.109090
# 7  -0.433678 -0.643978  0.353300 -1.102755 -0.472449 -1.142053  2.239393
# 8   0.410919 -0.590755 -0.587955 -0.185243  1.456796 -0.302368 -0.827833
# 9  -0.216533  2.212438 -0.169344  0.683710  0.668531  0.104961  0.676863
# 10 -0.263693 -1.011391 -0.880737 -0.563773 -1.864059 -1.478899 -0.030989
#
#       z_mean    i_mean    k_mean  ...    h_mean    c_mean   ch_mean   sh_mean  \
# ...

# %%
letters_curvature_max = []

for i in range(11):
    tmp = []
    for letter in letters:
        tmp.append(max(np.abs(letters_curvature[i][letter])))
    letters_curvature_max.append(tmp)

# %%
max_df = pd.DataFrame(letters_curvature_max, columns = [i + '_max' for i in letters])
max_df
# Out:
#          a_max        b_max        v_max       g_max       d_max      ye_max  \
# 0    63.548237  4937.128169   141.454709  131.900878  141.816038  106.201490
# 1   179.980944   134.133820   141.731680  114.529732  195.556561  122.109509
# 2   583.862372   247.653279  2430.288724  127.954096  113.284596  153.264753
# 3    58.417326   187.340065   607.139206   91.464296  224.298875  144.664338
# 4    71.979349   240.487122   386.298334  106.032137  160.520111   58.703145
# 5    83.614416   232.647058   132.353649  122.071894   93.171760   83.122634
# 6    68.028957   235.241154   359.593344  130.525624  292.962962   78.263341
# 7    36.534153    76.190211   311.175023   64.463009   84.642261   50.372698
# 8   457.141497    57.187164   137.958773   53.202672  207.549319   39.823136
# 9    75.107182  4114.273475   152.635748   77.352729  201.707992   53.494218
# 10   63.077353    18.501817   160.211128   57.736688   34.975832   82.632980
#
# ...

# %%
scaler = StandardScaler()
max_df_scaled = pd.DataFrame(scaler.fit_transform(max_df), columns = [i + '_max' for i in letters])
max_df_scaled
# Out:
#        a_max     b_max     v_max     g_max     d_max    ye_max    zh_max  \
# 0  -0.537498  2.350478 -0.481879  1.171887 -0.244133  0.483119 -0.196636
# 1   0.122995 -0.482955 -0.481448  0.572632  0.513404  0.915407 -0.109027
# 2   2.414109 -0.415987  3.081387  1.035735 -0.646318  1.762026  1.317410
# 3  -0.566604 -0.451567  0.243101 -0.223060  0.918561  1.528317 -0.234375
# 4  -0.489670 -0.420214 -0.100705  0.279489  0.019523 -0.807612 -1.165848
# 5  -0.423668 -0.424839 -0.496047  0.832815 -0.929832 -0.144031  0.130870
# 6  -0.512080 -0.423309 -0.142280  1.124445  1.886463 -0.276079 -0.729342
# 7  -0.690742 -0.517138 -0.217657 -1.154528 -1.050065 -1.033986  2.435999
# 8   1.695254 -0.528349 -0.487321 -1.542978  0.682456 -1.320662 -1.047504
# 9  -0.471927  1.865051 -0.464472 -0.709869  0.600115 -0.949161 -0.464121
# 10 -0.540169 -0.551170 -0.452679 -1.386567 -1.750173 -0.157337  0.062573
#
#        z_max     i_max     k_max  ...     h_max     c_max    ch_max    sh_max  \
# ...

# %%
letters_curvature_big_pct = []

for i in range(11):
    tmp = []
    for letter in letters:
        tmp.append(len(np.array(letters_curvature[i][letter])[np.abs(letters_curvature[i][letter]) > 50])/len(letters_curvature[i][letter]))
    letters_curvature_big_pct.append(tmp)

# %%
big_pct_df = pd.DataFrame(letters_curvature_big_pct, columns = [i + '_big_pct' for i in letters])
big_pct_df
# Out:
#     a_big_pct  b_big_pct  v_big_pct  g_big_pct  d_big_pct  ye_big_pct  \
# 0    0.006452   0.049261   0.026415   0.050000   0.038760    0.041667
# 1    0.049383   0.032110   0.034759   0.057143   0.019900    0.015152
# 2    0.045752   0.034161   0.035088   0.016393   0.025862    0.021739
# 3    0.009434   0.066327   0.014085   0.052632   0.037267    0.036496
# 4    0.010870   0.041176   0.028037   0.054795   0.028169    0.016393
# 5    0.007937   0.052133   0.018868   0.094891   0.021807    0.029630
# 6    0.024390   0.055375   0.019324   0.030675   0.032075    0.013333
# 7    0.000000   0.018519   0.058394   0.031250   0.017182    0.012048
# 8    0.011628   0.019512   0.024324   0.014493   0.059113    0.000000
# 9    0.029703   0.021277   0.036066   0.077922   0.037534    0.014706
# 10   0.029412   0.000000   0.015873   0.013514   0.000000    0.018182
#
#     zh_big_pct  z_big_pct  i_big_pct  k_big_pct  ...  h_big_pct  c_big_pct  \
# ...

# %%
scaler = StandardScaler()
big_pct_df_scaled = pd.DataFrame(scaler.fit_transform(big_pct_df), columns = [i + '_big_pct' for i in letters])
big_pct_df_scaled
# Out:
#     a_big_pct  b_big_pct  v_big_pct  g_big_pct  d_big_pct  ye_big_pct  \
# 0   -0.890184   0.737446  -0.155818   0.202377   0.686561    1.917062
# 1    1.839728  -0.177734   0.536217   0.484842  -0.623879   -0.422572
# 2    1.608834  -0.068271   0.563450  -1.126596  -0.209637    0.158703
# 3   -0.700541   1.648062  -1.178461   0.306443   0.582846    1.460846
# 4   -0.609254   0.306050  -0.021273   0.391976  -0.049338   -0.312988
# 5   -0.795762   0.890676  -0.781746   1.977575  -0.491415    0.854942
# 6    0.250502   1.063664  -0.743949  -0.561837   0.222104   -0.583005
# 7   -1.300430  -0.902984   2.496380  -0.539093  -0.812766   -0.696402
# 8   -0.561032  -0.849961  -0.329217  -1.201759   2.100841   -1.759506
# 9    0.588328  -0.755812   0.644548   1.306557   0.601359   -0.461894
# 10   0.569811  -1.891136  -1.030130  -1.240483  -2.006675   -0.155186
#
#     zh_big_pct  z_big_pct  i_big_pct  k_big_pct  ...  h_big_pct  c_big_pct  \
# ...

# %% [markdown]
# **1 Кластеризация со всеми параметрами**

# %%
X = pd.concat([max_df_scaled, mean_df_scaled, big_pct_df_scaled], axis = 1)
X
# Out:
#        a_max     b_max     v_max     g_max     d_max    ye_max    zh_max  \
# 0  -0.537498  2.350478 -0.481879  1.171887 -0.244133  0.483119 -0.196636
# 1   0.122995 -0.482955 -0.481448  0.572632  0.513404  0.915407 -0.109027
# 2   2.414109 -0.415987  3.081387  1.035735 -0.646318  1.762026  1.317410
# 3  -0.566604 -0.451567  0.243101 -0.223060  0.918561  1.528317 -0.234375
# 4  -0.489670 -0.420214 -0.100705  0.279489  0.019523 -0.807612 -1.165848
# 5  -0.423668 -0.424839 -0.496047  0.832815 -0.929832 -0.144031  0.130870
# 6  -0.512080 -0.423309 -0.142280  1.124445  1.886463 -0.276079 -0.729342
# 7  -0.690742 -0.517138 -0.217657 -1.154528 -1.050065 -1.033986  2.435999
# 8   1.695254 -0.528349 -0.487321 -1.542978  0.682456 -1.320662 -1.047504
# 9  -0.471927  1.865051 -0.464472 -0.709869  0.600115 -0.949161 -0.464121
# 10 -0.540169 -0.551170 -0.452679 -1.386567 -1.750173 -0.157337  0.062573
#
#        z_max     i_max     k_max  ...  h_big_pct  c_big_pct  ch_big_pct  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.metrics import v_measure_score
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist

# %% [markdown]
# **1.1 Через DBSCAN**

# %%
from sklearn.neighbors import NearestNeighbors

nearest_neighbors = NearestNeighbors(n_neighbors=3)
neighbors = nearest_neighbors.fit(X)

distances, indices = neighbors.kneighbors(X)
distances = np.sort(distances[:,2], axis=0)

fig = plt.figure(figsize=(5, 5))
plt.plot(distances)
plt.xlabel("Points")
plt.ylabel("Distance")
# Out:
# Text(0, 0.5, 'Distance')

# %%
from kneed import KneeLocator

i = np.arange(len(distances))
knee = KneeLocator(i, distances, S=1, curve='convex', direction='increasing', interp_method='polynomial')

fig = plt.figure(figsize=(5, 5))
knee.plot_knee()
plt.xlabel("Points")
plt.ylabel("Distance")

print(distances[knee.knee])
# Out:
# 12.2330075540912

# %%
dbscan_cluster = DBSCAN(eps=12.2330075540912, min_samples=2)
dbscan_cluster.fit(X)
plt.scatter(X['a_max'], 
            X['k_big_pct'], 
            c=dbscan_cluster.labels_)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")

labels=dbscan_cluster.labels_
N_clus=len(set(labels))-(1 if -1 in labels else 0)
print('Estimated no. of clusters: %d' % N_clus)

n_noise = list(dbscan_cluster.labels_).count(-1)
print('Estimated no. of noise points: %d' % n_noise)
# Out:
# Estimated no. of clusters: 1
# Estimated no. of noise points: 3

# %% [markdown]
# **Через K-means**

# %%
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 10)
 
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(X)
 
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / X.shape[0])
    inertias.append(kmeanModel.inertia_)
 
    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / X.shape[0]
    mapping2[k] = kmeanModel.inertia_
# Out:
# E:\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# E:\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# E:\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# E:\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
# ...

# %%
plt.plot(K, distortions, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Distortion')
plt.title('The Elbow Method using Distortion')
plt.show()

# %%
plt.plot(K, inertias, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Inertia')
plt.title('The Elbow Method using Inertia')
plt.show()

# %%
kmeans = KMeans(n_clusters=2, \
                init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X)
plt.scatter(X['c_big_pct'], X['h_max'], c=y_kmeans)
plt.scatter(kmeans.cluster_centers_[:, 0],\
            kmeans.cluster_centers_[:, 1], \
            s=100, c='red')
plt.title('K-means clustering (k={})'.format(k))
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# E:\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# E:\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# **Используя только среднюю кривизну**

# %%
X = mean_df_scaled
X
# Out:
#       a_mean    b_mean    v_mean    g_mean    d_mean   ye_mean   zh_mean  \
# 0  -0.946846  1.904327 -0.121969  0.680597  0.293164  1.900644  0.632026
# 1   0.789428 -0.450036 -0.259686  0.589787 -0.847571 -0.177047 -0.185480
# 2   2.735432 -0.521205  2.824788 -1.482409  0.562000  0.210937 -0.108557
# 3  -0.765259 -0.213986 -0.400250 -0.093331  0.896322  1.277417 -0.509352
# 4   0.048250 -0.133780  0.652624  0.633496  0.511694  0.543237 -2.016518
# 5  -0.763536 -0.307585 -0.908012  2.031320 -1.556723  0.353813  0.239535
# 6  -0.594484 -0.244049 -0.502758 -1.191399  0.352295 -1.290642 -0.109090
# 7  -0.433678 -0.643978  0.353300 -1.102755 -0.472449 -1.142053  2.239393
# 8   0.410919 -0.590755 -0.587955 -0.185243  1.456796 -0.302368 -0.827833
# 9  -0.216533  2.212438 -0.169344  0.683710  0.668531  0.104961  0.676863
# 10 -0.263693 -1.011391 -0.880737 -0.563773 -1.864059 -1.478899 -0.030989
#
#       z_mean    i_mean    k_mean  ...    h_mean    c_mean   ch_mean   sh_mean  \
# ...

# %%
from sklearn.neighbors import NearestNeighbors

n = 4
nearest_neighbors = NearestNeighbors(n_neighbors=n)
neighbors = nearest_neighbors.fit(X)

distances, indices = neighbors.kneighbors(X)
distances = np.sort(distances[:,n-1], axis=0)

fig = plt.figure(figsize=(5, 5))
plt.plot(distances)
plt.xlabel("Points")
plt.ylabel("Distance")
# Out:
# Text(0, 0.5, 'Distance')

# %%
from kneed import KneeLocator

i = np.arange(len(distances))
knee = KneeLocator(i, distances, S=1, curve='convex', direction='increasing', interp_method='polynomial')

fig = plt.figure(figsize=(5, 5))
knee.plot_knee()
plt.xlabel("Points")
plt.ylabel("Distance")

print(distances[knee.knee])
# Out:
# 6.8529685804497875

# %%
dbscan_cluster = DBSCAN(eps=6.8529685804497875, min_samples=2)
dbscan_cluster.fit(X)

plt.scatter(X['a_mean'], 
            X['r_mean'], 
            c=dbscan_cluster.labels_)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")

labels=dbscan_cluster.labels_
N_clus=len(set(labels))-(1 if -1 in labels else 0)
print('Estimated no. of clusters: %d' % N_clus)

n_noise = list(dbscan_cluster.labels_).count(-1)
print('Estimated no. of noise points: %d' % n_noise)
# Out:
# Estimated no. of clusters: 1
# Estimated no. of noise points: 4

# %%
control_mean = []


for letter in letters:
    control_mean.append(np.abs(control_curvature[letter]).mean())

# %%
control_mean_df = pd.DataFrame([control_mean], columns = [i + '_mean' for i in letters])
control_mean_df
# Out:
#      a_mean    b_mean    v_mean    g_mean    d_mean   ye_mean    zh_mean  \
# 0  3.785231  6.937706  6.001743  6.355572  6.410822  5.029343  13.889898
#
#     z_mean    i_mean    k_mean  ...     h_mean    c_mean   ch_mean   sh_mean  \
# 0  6.93196  5.401531  9.276906  ...  11.274999  5.740802  4.717081  8.868861
#
#    sha_mean   bl_mean  myagk_mean    e_mean   u_mean   ya_mean
# 0  10.56016  5.217439    2.695616  7.568108  3.94368  6.658932
#
# [1 rows x 30 columns]

# %%
tmp = []
for letter in letters:
    print(letter + ': ', end = '')
    tmp.append(len(mean_df[letter + '_mean'].loc[mean_df[letter +'_mean'] > control_mean_df[letter + '_mean'][0]])/ len(mean_df[letter + '_mean']))
    print(tmp[-1])
print(np.array(tmp).mean())
# Out:
# a: 1.0
# b: 0.8181818181818182
# v: 0.8181818181818182
# g: 1.0
# d: 0.7272727272727273
# ye: 0.8181818181818182
# zh: 0.8181818181818182
# z: 0.9090909090909091
# i: 1.0
# k: 0.9090909090909091
# l: 0.9090909090909091
# m: 0.9090909090909091
# n: 0.9090909090909091
# o: 1.0
# p: 0.7272727272727273
# r: 1.0
# s: 0.6363636363636364
# t: 0.9090909090909091
# y: 1.0
# ph: 0.2727272727272727
# h: 0.5454545454545454
# c: 1.0
# ch: 1.0
# sh: 0.8181818181818182
# sha: 0.9090909090909091
# bl: 1.0
# myagk: 1.0
# e: 0.9090909090909091
# u: 1.0
# ya: 1.0
# 0.8757575757575757
